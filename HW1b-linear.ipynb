# %%
##This is a Jupyter notebook for Linear Algebra HW. 
##Belongs to Divya E. Vernerey
##August 2023

# %% [markdown]
# # HW1 - LINEAR
#
# Today we will try to understand how systems of linear equations look like graphically.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
''' 
This cell will graph lines
and also beautify the graph environment
'''

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

## This call to linspace produces an array of 100 numbers evenly spaced on the interval [-5,5]
x=np.linspace(-5,5,100)

#graph lines
fig, ax = plt.subplots()
#ax.plot(x,(5-x)/3)
#ax.plot(x,(5+x)/2)
ax.plot(x,(5-x)/3)
ax.plot(x,-x/3)

#text of line equations
ax.text(1,1.6,'$x_1+3x_2 = 5$')
ax.text(-3,0.5,'$x_1-2x_2 = -5$')

ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)

## This options specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')

# %% [markdown]
# # EXERCISES:

# %% [markdown]
# Exercise 1: Consider the system of equations given below. Find a value for the coefficient $a$
# so that the system has exactly one solution.
# For that value of $a$, find the solution to the system of equations and plot the lines formed by your equations to check your answer.

# %% [markdown]
# $$𝑎 𝑥_1 + 2𝑥_2 = 1 \\ 4 𝑥_1 + 8 𝑥_2 = 12$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

## This call to linspace produces an array of 100 numbers evenly spaced on the interval [-5,5]
x=np.linspace(-5,5,100)

#graph lines
fig, ax = plt.subplots()
#ax.plot(x,(5-x)/3)
#ax.plot(x,(5+x)/2)
ax.plot(x,1/5 -x)
ax.plot(x,(3-x)/2)

#text of line equations
ax.text(1,1.6,'$1/5x_1 + 2x_2 = 1$')
ax.text(-3,0.5,'$4x_1 + 8x_2 = 12$')

ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)

## This options specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')

# %% [markdown]
# Exercise 2: Find a value for the coefficient $a$ so that the system has no solution. Plot the lines formed by your equations to verify there is no solution.
#
# $$𝑎 𝑥_1 + 2𝑥_2 = 1 \\ 4𝑥_1 + 8𝑥_2 = 12$$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

## This call to linspace produces an array of 100 numbers evenly spaced on the interval [-5,5]
x=np.linspace(-5,5,100)

#graph lines
fig, ax = plt.subplots()
#ax.plot(x,(5-x)/3)
#ax.plot(x,(5+x)/2)
ax.plot(x,(1-x)/2)
ax.plot(x,(3-x)/2)

#text of line equations
ax.text(1,1.6,'$x_1+2x_2 = 1$')
ax.text(-3,0.5,'$4x_1 + 8x_2 = 12$')

ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)

## This options specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')

# %% [markdown]
# Exercise 3: Consider the system of equations given below. Under what conditions on the coefficients $a,b,c,d,e,f$
# does this system have only one solution? No solutions? An infinite number of solutions?
# (Think about what must be true of the slopes AND intercepts of the lines in each case.)
#
# $$𝑎 𝑥_1 + 𝑏 𝑥_2=c \\ 𝑑 𝑥_1 + 𝑒 𝑥_2=𝑓$$

# %%
## Code solution here.
#For there to be one unique solution, the two equations must have different slopes.
#This means that a != d and b != e.

#For there to be no solutions, the two equations must have the same exact slope. 
#This means that they will always be parallel and never intersects. However, the values of
#constants on the right side of the equation must differ. Thus, c != f, a = d, b = e.

#For there to be infinite solutions the two lines must overlap completely.
#You must have the slopes to be equal and the constants on the right side of the equation to be equal.
#Thus, you must have a = d, b = e, c = f.
